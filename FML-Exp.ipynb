# %% [markdown]
# <h2>I checked each user experience for all algorithms. When Competition is 5, I checked 1st, 3rd and 5th User Experience, When Competition is 10, I checked 1st, 5th and 10th User Experience, and When Competition is 15, I checked 1st, 10th, and 15th User Experience</h2>
#
# <br>
#
# <h3>Beggining , Middle and Last User Experience</h3>

# %%
import numpy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")

# %%
df = pd.read_csv("Percentile - Sheet1.csv")

# %%
#df.columns

# %%
#df['Algorithms'].unique()

# %%
#df['Algorithms'].unique()

# %%
#Competition = df[(df['Competition'] == 5) & (df['Algorithms'] == 'conv')]
#Nodes = Competition[(Competition['Hosts'] == 1) | (Competition['Hosts'] == 3) | (Competition['Hosts'] == 5)]
#D10 = Nodes[(Nodes['Delay'] == 10) ]
#D100 = Nodes[(Nodes['Delay'] == 100) ]

# %%
#nodesColors = ["#3f8a27", "#fac507", "#fa0707"]

# %%
#D5MB.to_csv('T.csv')

#g = sns.FacetGrid(D100, col="Bandwidth" , hue='Hosts', palette=nodesColors,hue_kws={"marker": ["*", "o","x"]})
#g.map(plt.scatter, "MOS", "Percentile")
#g.add_legend(title= 'Host #')

# %% [markdown]
# <h1>Delay 100 & Competition 5   -------- 1, 3, 5 user Experience on Each Algorithm</h1>

# %%
algos  = ['conv', 'arbiter', 'elastic', 'geometric', 'average','exponential', 'logistic', 'bba']

# %%
#algos[1]

# %%
for x in algos:
    #print(x)
    
    aSel = df[(df['Competition'] == 5) & (df['Algorithms'] == x)]
    Nodes = aSel[(aSel['Hosts'] == 1) | (aSel['Hosts'] == 3) | (aSel['Hosts'] == 5)]
    D100 = Nodes[(Nodes['Delay'] == 100) ]
    #print(D10)
    g = sns.FacetGrid(D100, col="Bandwidth",hue="Hosts",palette=nodesColors, hue_kws={"marker": ["*", "o","x"]})
    g.map(plt.scatter, "MOS", "Percentile")
    g.set_axis_labels("P.1203", "Percentile")
    axes = g.axes.flatten()
    axes[0].set_title("5 Mbps")
    axes[1].set_title("10 Mbps")
    axes[2].set_title("15 Mbps")
    g.add_legend(title= 'Host #')
    plt.subplots_adjust(top=0.80)
    g.fig.suptitle(x.capitalize() + ' Worst Case: delay 100 ms')

# %% [markdown]
# <h1>Delay 100 & Competition 10 -------- 1, 5, 10 user Experience on Each Algorithm</h1>

# %%
for x in algos:
    #print(x)
    
    aSel = df[(df['Competition'] == 10) & (df['Algorithms'] == x)]
    Nodes = aSel[(aSel['Hosts'] == 1) | (aSel['Hosts'] == 5) | (aSel['Hosts'] == 10)]
    D100 = Nodes[(Nodes['Delay'] == 100) ]
    #print(D10)
    g = sns.FacetGrid(D100, col="Bandwidth",hue="Hosts",palette=nodesColors, hue_kws={"marker": ["*", "o","x"]})
    g.map(plt.scatter, "MOS", "Percentile")
    g.set_axis_labels("P.1203", "Percentile")
    axes = g.axes.flatten()
    axes[0].set_title("5 Mbps")
    axes[1].set_title("10 Mbps")
    axes[2].set_title("15 Mbps")
    g.add_legend(title= 'Host #')
    plt.subplots_adjust(top=0.80)
    g.fig.suptitle(x.capitalize() + ' Worst Case: delay 100 ms')

# %% [markdown]
# <h1>Delay 100 & Competition 15 -------- 1, 10, 15 user Experience on Each Algorithm</h1>

# %%
for x in algos:
    #print(x)
    
    aSel = df[(df['Competition'] == 15) & (df['Algorithms'] == x)]
    Nodes = aSel[(aSel['Hosts'] == 1) | (aSel['Hosts'] == 10) | (aSel['Hosts'] == 15)]
    D100 = Nodes[(Nodes['Delay'] == 100) ]
    #print(D10)
    g = sns.FacetGrid(D100, col="Bandwidth",hue="Hosts",palette=nodesColors, hue_kws={"marker": ["*", "o","x"]})
    g.map(plt.scatter, "MOS", "Percentile")
    g.set_axis_labels("P.1203", "Percentile")
    axes = g.axes.flatten()
    axes[0].set_title("5 Mbps")
    axes[1].set_title("10 Mbps")
    axes[2].set_title("15 Mbps")
    g.add_legend(title= 'Host #')
    plt.subplots_adjust(top=0.80)
    g.fig.suptitle(x.capitalize() + ' Worst Case: delay 100 ms')

# %% [markdown]
# <h1>Delay 10 & Competition 5 -------- 1, 3, 5 user Experience on Each Algorithm</h1>

# %%
for x in algos:
    #print(x)
    
    aSel = df[(df['Competition'] == 5) & (df['Algorithms'] == x)]
    Nodes = aSel[(aSel['Hosts'] == 1) | (aSel['Hosts'] == 3) | (aSel['Hosts'] == 5)]
    D10 = Nodes[(Nodes['Delay'] == 10) ]
    #print(D10)
    g = sns.FacetGrid(D10, col="Bandwidth",hue="Hosts",palette=nodesColors, hue_kws={"marker": ["*", "o","x"]})
    g.map(plt.scatter, "MOS", "Percentile")
    g.set_axis_labels("P.1203", "Percentile")
    axes = g.axes.flatten()
    axes[0].set_title("5 Mbps")
    axes[1].set_title("10 Mbps")
    axes[2].set_title("15 Mbps")
    g.add_legend(title= 'Host #')
    plt.subplots_adjust(top=0.80)
    g.fig.suptitle(x.capitalize() + ' Best Case: delay 10 ms')

# %% [markdown]
# <h1>Delay 10 & Competition 10 -------- 1, 5, 10 user Experience on Each Algorithm</h1>

# %%
for x in algos:
    #print(x)
    
    aSel = df[(df['Competition'] == 10) & (df['Algorithms'] == x)]
    Nodes = aSel[(aSel['Hosts'] == 1) | (aSel['Hosts'] == 5) | (aSel['Hosts'] == 10)]
    D10 = Nodes[(Nodes['Delay'] == 10) ]
    #print(D10)
    g = sns.FacetGrid(D10, col="Bandwidth",hue="Hosts",palette=nodesColors, hue_kws={"marker": ["*", "o","x"]})
    g.map(plt.scatter, "MOS", "Percentile")
    g.set_axis_labels("P.1203", "Percentile")
    axes = g.axes.flatten()
    axes[0].set_title("5 Mbps")
    axes[1].set_title("10 Mbps")
    axes[2].set_title("15 Mbps")
    g.add_legend(title= 'Host #')
    plt.subplots_adjust(top=0.80)
    g.fig.suptitle(x.capitalize() + ' Best Case: delay 100 ms')

# %% [markdown]
# <h1>Delay 15 & Competition 15 -------- 1, 10, 15 user Experience on Each Algorithm</h1>

# %%
for x in algos:
    #print(x)
    
    aSel = df[(df['Competition'] == 15) & (df['Algorithms'] == x)]
    Nodes = aSel[(aSel['Hosts'] == 1) | (aSel['Hosts'] == 10) | (aSel['Hosts'] == 15)]
    D10 = Nodes[(Nodes['Delay'] == 10) ]
    #print(D10)
    g = sns.FacetGrid(D10, col="Bandwidth",hue="Hosts",palette=nodesColors, hue_kws={"marker": ["*", "o","x"]})
    g.map(plt.scatter, "MOS", "Percentile")
    g.set_axis_labels("P.1203", "Percentile")
    axes = g.axes.flatten()
    axes[0].set_title("5 Mbps")
    axes[1].set_title("10 Mbps")
    axes[2].set_title("15 Mbps")
    g.add_legend(title= 'Host #')
    plt.subplots_adjust(top=0.80)
    g.fig.suptitle(x.capitalize() + ' Best Case: delay 100 ms')
