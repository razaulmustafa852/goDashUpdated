# %% [markdown]
# <h2>I checked each user experience for all algorithms. When Competition is 5, I checked 1st, 3rd and 5th User Experience, When Competition is 10, I checked 1st, 5th and 10th User Experience, and When Competition is 15, I checked 1st, 10th, and 15th User Experience</h2>
#
# <br>
#
# <h3>Beggining , Middle and Last User Experience</h3>

# %%
import numpy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")

# %%
df = pd.read_csv("GoDash-18FEB - Sheet1.csv")

# %%
df.columns
# Out:
# Index(['total_stall_events', 'avg_stall', 'total_stalls', 'arr_first_seg_ms',
#        'switching_freq', 'amplitude_1', 'amplitude_2', 'bandwidth',
#        'packetloss', 'delay', 'competion', 'user', 'mpd', 'algorithm',
#        'packets_a_to_b', 'packets_b_to_a', 'rtt_avg', 'rtt_std',
#        'segment_size', 'througput_a2b', 'througput_b2a', 'delivery_rate',
#        'avg_vid_quality', 'min_quality', 'max_quality', '320x240', '384x288',
#        '512x384', '512x384.1', '640x480', '720x480', '1280x720', '1280x720.1',
#        '1920x1080', '1920x1080.1', 'rtt_application', 'seg_duration', 'p1203',
#        'Clae', 'Duanmu', 'Yin', 'Yu', 'FPS', 'Protocol', 'exp_ID'],
#       dtype='object')

# %%
competition = [5, 10 , 15]

# %%
#for c in range(2): 
 #   print(competition[c])

# %%
delays = [10, 50, 100]

# %%
nodesColors = ["#3f8a27", "#fac507", "#fa0707"]

# %%
algos  = ['conv', 'arbiter', 'elastic', 'geometric', 'average','exponential', 'logistic', 'bba']

# %%
for c in range(3): 
    for d in delays:
        
        for x in algos:
            if competition[c] == 5:
                aSel = df[(df['competion'] == 5) & (df['algorithm'] == x)]
                Nodes = aSel[(aSel['user'] == 1) | (aSel['user'] == 3) | (aSel['user'] == 5)]
                #D100 = Nodes[(Nodes['Delay'] == delays[d])]
                #print('135')
            elif competition[c] == 10:
                aSel = df[(df['competion'] == 10) & (df['algorithm'] == x)]
                Nodes = aSel[(aSel['user'] == 1) | (aSel['user'] == 5) | (aSel['user'] == 10)]
                #D100 = Nodes[(Nodes['Delay'] == delays[d])]
            elif competition[c] == 15:
                aSel = df[(df['competion'] == 15) & (df['algorithm'] == x)]
                Nodes = aSel[(aSel['user'] == 1) | (aSel['user'] == 10) | (aSel['user'] == 15)]
                #D100 = Nodes[(Nodes['Delay'] == delays[d])]
        
            D100 = Nodes[(Nodes['delay'] == d) ]
            g = sns.FacetGrid(D100, col="bandwidth",hue="user",palette=nodesColors, hue_kws={"marker": ["*", "o","x"]})
            g.map(plt.scatter, "p1203", "rtt_avg")
            g.set_axis_labels("P.1203", "rtt_avg")
            axes = g.axes.flatten()
            axes[0].set_title("5 Mbps")
            axes[1].set_title("10 Mbps")
            axes[2].set_title("15 Mbps")
            g.add_legend(title= 'Host #')
            plt.subplots_adjust(top=0.80)
            g.fig.suptitle(x.capitalize() + ' &  Delay '+str(d)+' ms, Nodes competitions '+ str(competition[c]) +'')
        print('delay '+ str(d) +' & competition '+ str(competition[c]) +' user experience on each algorithm')
# Out:
# delay 10 & competition 5 user experience on each algorithm
# delay 50 & competition 5 user experience on each algorithm
# delay 100 & competition 5 user experience on each algorithm
# delay 10 & competition 10 user experience on each algorithm
# delay 50 & competition 10 user experience on each algorithm
# delay 100 & competition 10 user experience on each algorithm
# delay 10 & competition 15 user experience on each algorithm
# delay 50 & competition 15 user experience on each algorithm
# delay 100 & competition 15 user experience on each algorithm

# %%
for c in range(3): 
    for d in delays:
        
        for x in algos:
            if competition[c] == 5:
                aSel = df[(df['competion'] == 5) & (df['algorithm'] == x)]
                Nodes = aSel[(aSel['user'] == 1) | (aSel['user'] == 3) | (aSel['user'] == 5)]
                #D100 = Nodes[(Nodes['Delay'] == delays[d])]
                #print('135')
            elif competition[c] == 10:
                aSel = df[(df['competion'] == 10) & (df['algorithm'] == x)]
                Nodes = aSel[(aSel['user'] == 1) | (aSel['user'] == 5) | (aSel['user'] == 10)]
                #D100 = Nodes[(Nodes['Delay'] == delays[d])]
            elif competition[c] == 15:
                aSel = df[(df['competion'] == 15) & (df['algorithm'] == x)]
                Nodes = aSel[(aSel['user'] == 1) | (aSel['user'] == 10) | (aSel['user'] == 15)]
                #D100 = Nodes[(Nodes['Delay'] == delays[d])]
        
            D100 = Nodes[(Nodes['delay'] == d) ]
            g = sns.FacetGrid(D100, col="bandwidth",hue="user",palette=nodesColors, hue_kws={"marker": ["*", "o","x"]})
            g.map(plt.scatter, "switching_freq", "total_stall_events")
            #g.set_axis_labels("P.1203", "rtt_avg")
            axes = g.axes.flatten()
            axes[0].set_title("5 Mbps")
            axes[1].set_title("10 Mbps")
            axes[2].set_title("15 Mbps")
            g.add_legend(title= 'Host #')
            plt.subplots_adjust(top=0.80)
            g.fig.suptitle(x.capitalize() + ' &  Delay '+str(d)+' ms, Nodes competitions '+ str(competition[c]) +'')
        print('delay '+ str(d) +' & competition '+ str(competition[c]) +' user experience on each algorithm')
# Out:
# delay 10 & competition 5 user experience on each algorithm
# delay 50 & competition 5 user experience on each algorithm
# delay 100 & competition 5 user experience on each algorithm
# delay 10 & competition 10 user experience on each algorithm
# delay 50 & competition 10 user experience on each algorithm
# delay 100 & competition 10 user experience on each algorithm
# delay 10 & competition 15 user experience on each algorithm
# delay 50 & competition 15 user experience on each algorithm
# delay 100 & competition 15 user experience on each algorithm

# %%
for c in range(3): 
    for d in delays:
        
        for x in algos:
            if competition[c] == 5:
                aSel = df[(df['competion'] == 5) & (df['algorithm'] == x)]
                Nodes = aSel[(aSel['user'] == 1) | (aSel['user'] == 3) | (aSel['user'] == 5)]
                #D100 = Nodes[(Nodes['Delay'] == delays[d])]
                #print('135')
            elif competition[c] == 10:
                aSel = df[(df['competion'] == 10) & (df['algorithm'] == x)]
                Nodes = aSel[(aSel['user'] == 1) | (aSel['user'] == 5) | (aSel['user'] == 10)]
                #D100 = Nodes[(Nodes['Delay'] == delays[d])]
            elif competition[c] == 15:
                aSel = df[(df['competion'] == 15) & (df['algorithm'] == x)]
                Nodes = aSel[(aSel['user'] == 1) | (aSel['user'] == 10) | (aSel['user'] == 15)]
                #D100 = Nodes[(Nodes['Delay'] == delays[d])]
        
            D100 = Nodes[(Nodes['delay'] == d) ]
            g = sns.FacetGrid(D100, col="bandwidth",hue="user",palette=nodesColors, hue_kws={"marker": ["*", "o","x"]})
            g.map(plt.scatter, "delivery_rate", "througput_b2a")
            #g.set_axis_labels("P.1203", "rtt_avg")
            axes = g.axes.flatten()
            axes[0].set_title("5 Mbps")
            axes[1].set_title("10 Mbps")
            axes[2].set_title("15 Mbps")
            g.add_legend(title= 'Host #')
            plt.subplots_adjust(top=0.80)
            g.fig.suptitle(x.capitalize() + ' &  Delay '+str(d)+' ms, Nodes competitions '+ str(competition[c]) +'')
        print('delay '+ str(d) +' & competition '+ str(competition[c]) +' user experience on each algorithm')
# Out:
# delay 10 & competition 5 user experience on each algorithm
# delay 50 & competition 5 user experience on each algorithm
# delay 100 & competition 5 user experience on each algorithm
# delay 10 & competition 10 user experience on each algorithm
# delay 50 & competition 10 user experience on each algorithm
# delay 100 & competition 10 user experience on each algorithm
# delay 10 & competition 15 user experience on each algorithm
# delay 50 & competition 15 user experience on each algorithm
# delay 100 & competition 15 user experience on each algorithm
